# %%
# Student Management System

students = {}

def add_student():
    roll = input("Enter Roll Number: ")
    if roll in students:
        print("Student already exists!\n")
        return
    name = input("Enter Name: ")
    marks = int(input("Enter Marks: "))
    students[roll] = {"name": name, "marks": marks}
    print("Student added successfully!\n")

def view_students():
    if not students:
        print("No student records found!\n")
        return
    print("\nStudent Records:")
    print("Roll\tName\tMarks\tResult")
    for roll, data in students.items():
        result = "Pass" if data["marks"] >= 35 else "Fail"
        print(f"{roll}\t{data['name']}\t{data['marks']}\t{result}")
    print()

def search_student():
    roll = input("Enter Roll Number to search: ")
    if roll in students:
        data = students[roll]
        result = "Pass" if data["marks"] >= 35 else "Fail"
        print(f"Name: {data['name']}")
        print(f"Marks: {data['marks']}")
        print(f"Result: {result}\n")
    else:
        print("Student not found!\n")

def update_marks():
    roll = input("Enter Roll Number to update marks: ")
    if roll in students:
        new_marks = int(input("Enter new marks: "))
        students[roll]["marks"] = new_marks
        print("Marks updated successfully!\n")
    else:
        print("Student not found!\n")

def delete_student():
    roll = input("Enter Roll Number to delete: ")
    if roll in students:
        del students[roll]
        print("Student record deleted!\n")
    else:
        print("Student not found!\n")

while True:
    print("===== Student Management System =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Marks")
    print("5. Delete Student")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()
    elif choice == "2":
        view_students()
    elif choice == "3":
        search_student()
    elif choice == "4":
        update_marks()
    elif choice == "5":
        delete_student()
    elif choice == "6":
        print("Exiting Student Management System. Goodbye!")
        break
    else:
        print("Invalid choice! Try again.\n")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Marks
# 5. Delete Student
# 6. Exit
# Enter your choice: 1
# Enter Roll Number: 44
# Enter Name: jaanu
# Enter Marks: 67
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Marks
# 5. Delete Student
# 6. Exit
# Enter your choice: 6
# Exiting Student Management System. Goodbye!
